# %% [markdown]
# # Imports

# %%
import importlib.metadata
import pandas as pd
import warnings
from datetime import datetime
from pathlib import Path
import matplotlib.pyplot as plt

from diive.core.io.filereader import search_files, MultiDataFileReader
from diive.core.io.files import save_parquet, load_parquet
# pd.options.display.width = None
# pd.options.display.max_columns = None
pd.set_option('display.max_rows', 3000)
pd.set_option('display.max_columns', 3000)
warnings.filterwarnings(action='ignore', category=FutureWarning)
warnings.filterwarnings(action='ignore', category=UserWarning)
dt_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
version_diive = importlib.metadata.version("diive")
print(f"diive version: v{version_diive}")
# Out:
# diive version: v0.80.0

# %% [markdown]
# # **IRGA + QCL + LGR**: Load merged L1 results from parquet (available vars only)

# %%
df = load_parquet(filepath="41.1_CH-CHA_IRGA_LGR+QCL_Level-1_eddypro_fluxnet_2005-2023_meteo7.parquet")
display(df.head(3))
display(df.tail(3))
# Out:
# Loaded .parquet file 41.1_CH-CHA_IRGA_LGR+QCL_Level-1_eddypro_fluxnet_2005-2023_meteo7.parquet (0.741 seconds). Detected time resolution of <30 * Minutes> / 30min
# ...

# %% [markdown]
# # Plots

# %%
subset = ['FC', 'FH2O', 'FN2O', 'FCH4', 'TA_T1_2_1']
df[subset].plot(subplots=True, x_compat=True, figsize=(14, 6));

# %% [markdown]
# # **End of notebook**.

# %%
dt_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Finished. {dt_string}")
# Out:
# Finished. 2024-09-23 10:40:54
